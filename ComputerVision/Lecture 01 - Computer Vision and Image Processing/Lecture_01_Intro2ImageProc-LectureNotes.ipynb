# %% [markdown]
# <a href="https://colab.research.google.com/github/andrehochuli/teaching/blob/main/ComputerVision/Lecture%2001%20-%20Computer%20Vision%20and%20Image%20Processing/Lecture_01_Intro2ImageProc-LectureNotes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow # for image display

# %%
#Getting retrieving some imagens from URL
# !wget https://logodix.com/logo/627975.png -O pucpr.png

# !wget https://static.mundoeducacao.uol.com.br/vestibular/2022/04/puc-pr-bibliotecacentral-divulgacao.jpg -O campus.png

# !wget https://programmer.ink/images/think/c080fb939e166165e5f25d63cbf0e86e.jpg -O digit3.png
# Out:
# --2024-07-29 22:08:23--  https://logodix.com/logo/627975.png
# Resolving logodix.com (logodix.com)... 104.26.15.246, 172.67.72.60, 104.26.14.246, ...
# Connecting to logodix.com (logodix.com)|104.26.15.246|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8440 (8.2K) [image/png]
# Saving to: ‘pucpr.png’
#
# pucpr.png           100%[===================>]   8.24K  --.-KB/s    in 0s
#
# 2024-07-29 22:08:23 (62.0 MB/s) - ‘pucpr.png’ saved [8440/8440]
#
# --2024-07-29 22:08:23--  https://static.mundoeducacao.uol.com.br/vestibular/2022/04/puc-pr-bibliotecacentral-divulgacao.jpg
# Resolving static.mundoeducacao.uol.com.br (static.mundoeducacao.uol.com.br)... 200.147.4.47
# Connecting to static.mundoeducacao.uol.com.br (static.mundoeducacao.uol.com.br)|200.147.4.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88360 (86K) [image/jpeg]
# Saving to: ‘campus.png’
#
# campus.png          100%[===================>]  86.29K   314KB/s    in 0.3s
#
# 2024-07-29 22:08:24 (314 KB/s) - ‘campus.png’ saved [88360/88360]
#
# --2024-07-29 22:08:24--  https://programmer.ink/images/think/c080fb939e166165e5f25d63cbf0e86e.jpg
# Resolving programmer.ink (programmer.ink)... 84.247.140.141
# Connecting to programmer.ink (programmer.ink)|84.247.140.141|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2191 (2.1K) [image/jpeg]
# Saving to: ‘digit3.png’
#
# digit3.png          100%[===================>]   2.14K  --.-KB/s    in 0s
#
# 2024-07-29 22:08:25 (799 MB/s) - ‘digit3.png’ saved [2191/2191]

# %% [markdown]
# #Manipulating Images With Opencv

# %%
#Loading a color image from disk
img_color = cv2.imread('pucpr.png',cv2.IMREAD_COLOR)
print(img_color.shape)
cv2_imshow(img_color)
# Out:
# (290, 290, 3)
# <PIL.Image.Image image mode=RGB size=290x290>

# %%
#Loading a gray image from disk
img_gray = cv2.imread('pucpr.png', cv2.IMREAD_GRAYSCALE)
print(img_gray.shape)
cv2_imshow(img_gray)
# Out:
# (290, 290)
# <PIL.Image.Image image mode=L size=290x290>

# %%
#Loading a color image from disk and convert to grayscale
img_color = cv2.imread('pucpr.png',cv2.IMREAD_COLOR)

#Convert Function
img_gray = cv2.cvtColor(img_color, cv2.COLOR_BGR2GRAY)

print(img_color.shape, img_gray.shape)
cv2_imshow(img_color)
cv2_imshow(img_gray)
# Out:
# (290, 290, 3) (290, 290)
# <PIL.Image.Image image mode=RGB size=290x290>
# <PIL.Image.Image image mode=L size=290x290>

# %%
#Upscale and Downscale
original = cv2.imread('campus.png',cv2.IMREAD_COLOR)
print(original.shape)
cv2_imshow(original)
# Out:
# (400, 600, 3)
# <PIL.Image.Image image mode=RGB size=600x400>

# %%
print("Downscale 3x")
#Downscale by 3x from original
width = int(original.shape[1]/3) #[400,600,3]
height = int(original.shape[0]/3)

img_down = cv2.resize(original,(width,height))
print(img_down.shape)
cv2_imshow(img_down)
# Out:
# Downscale 3x
# (133, 200, 3)
# <PIL.Image.Image image mode=RGB size=200x133>

# %%
print("Resize to 128x128")
#Downscale to a fixed size 128x128
img_down = cv2.resize(original,(128,128))
print(img_down.shape)
cv2_imshow(img_down)
# Out:
# Resize to 128x128
# (128, 128, 3)
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
print("Upscale from 128x128 to 640x640")
#Downscale to a fixed size 128x128
img_up = cv2.resize(img_down,(640,640),None)
print(img_up.shape)
cv2_imshow(img_up)
# Out:
# Upscale from 128x128 to 640x640
# (640, 640, 3)
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
#Lets show the pixels with a simple digit image (grayscale)
img_digit = cv2.imread('digit3.png',cv2.IMREAD_GRAYSCALE)
img_down = cv2.resize(img_digit,(32,32))
print(img_down.shape)
cv2_imshow(img_down)

for y in range(img_down.shape[0]):
  for x in range(img_down.shape[1]):
    print('%03d' % (img_down[y][x]), end=' ')
  print('')
# Out:
# (32, 32)
# <PIL.Image.Image image mode=L size=32x32>
# 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 031 131 254 253 254 254 213 081 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 000 000 021 142 233 252 253 252 253 253 252 223 020 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 123 123 254 253 254 253 224 203 203 203 223 255 213 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 203 203 253 252 253 211 020 000 000 000 060 253 252 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 040 243 243 224 203 183 040 152 030 000 000 000 255 253 102 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 040 040 020 000 000 102 253 050 000 000 081 253 252 020 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 040 040 020 000 000 102 253 050 000 000 081 253 252 020 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 081 214 031 113 113 233 254 233 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 000 000 062 102 081 040 253 232 253 253 252 233 050 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 000 000 152 253 254 253 254 253 254 254 233 123 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 000 000 152 252 253 252 253 252 192 192 050 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 000 000 062 183 203 243 254 253 062 062 000 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 040 172 252 203 203 020 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 021 000 000 000 000 000 000 000 000 000 000 183 254 254 112 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 021 000 000 000 000 000 000 000 000 000 000 183 254 254 112 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 062 203 163 000 000 000 000 000 000 000 000 000 060 253 253 151 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 021 214 192 000 000 000 000 000 000 000 000 000 011 213 254 254 151 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 102 253 151 000 000 000 000 000 000 000 000 040 213 252 253 253 111 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 040 255 213 092 051 000 000 000 031 092 173 253 254 253 142 142 000 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 172 252 253 252 203 203 203 233 252 253 252 253 130 020 020 000 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 021 203 255 253 254 253 253 254 253 243 203 081 000 000 000 000 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 020 151 151 253 171 171 151 151 040 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 018 139 139 233 158 158 139 139 037 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000
# 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000 000

# %%
#binarization (threshold)
#the pixels below the threshold is moved to 0, and the others to 1 (or 255)

_,img_thresh = cv2.threshold(img_down,127,1,cv2.THRESH_BINARY)
print(img_thresh.shape)
#Multiply to 255 to visualize
cv2_imshow(img_thresh*255)

for y in range(img_thresh.shape[0]):
  for x in range(img_thresh.shape[1]):
    print('%d' % (img_thresh[y][x]), end='')
  print('')
# Out:
# (32, 32)
# <PIL.Image.Image image mode=L size=32x32>
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000001111110000000000
# 00000000000000111111111000000000
# 00000000000001111111111100000000
# 00000000000111111000001100000000
# 00000000000111110100001100000000
# 00000000000000000100001100000000
# 00000000000000000100001100000000
# 00000000000000000100011100000000
# 00000000000000000111111000000000
# 00000000000001111111110000000000
# 00000000000001111111100000000000
# 00000000000000111110000000000000
# 00000000000000000111100000000000
# 00000000000000000011100000000000
# 00000000000000000011100000000000
# 00000001100000000001110000000000
# 00000011000000000011110000000000
# 00000011000000000111100000000000
# 00000011000000011111100000000000
# 00000011111111111110000000000000
# 00000001111111111000000000000000
# 00000000111111100000000000000000
# 00000000111111100000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000

# %% [markdown]
# #Drawing Functions
# https://docs.opencv.org/4.5.2/dc/da5/tutorial_py_drawing_functions.html

# %%
img = np.zeros((512,512,3), np.uint8)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
cv2.line(img,(0,0),(511,511),(80,80,120),5) #BGr (255,0,0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
cv2.rectangle(img,(384,0),(510,128),(0,255,0),3)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
cv2.circle(img,(447,63), 63, (0,255,255), -1)

pt = (320,256)

cv2.circle()img,pt, 20, (100,76,255), 5)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
for i in range(0,256):
  img[200,i] = (80,200,255)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
#Accessing a specific pixel
val = img_color[10,10]
print(val, img_color.shape)
cv2_imshow(img_color)

val = img_gray[10,10]
print(val)
print(val, img_gray.shape)
cv2_imshow(img_gray)
# Out:
# [255 255 255] (290, 290, 3)
# <PIL.Image.Image image mode=RGB size=290x290>
# 255
# 255 (290, 290)
# <PIL.Image.Image image mode=L size=290x290>

# %% [markdown]
# #Practice 1
#
# Compute a image histogram for the PUCPR Logo in grayscale. You need to implement by your own. Do not use Opencv Functions.
#
# The histogram compute the frequencies of each pixel value (0-255)

# %% [markdown]
# #Practice 2
#
# Extract each channel from the color image and show them. You can use any image.

# %%
#Implement Practice 2 here
# !wget https://upload.wikimedia.org/wikipedia/commons/thumb/e/e0/Synthese%2B.svg/1200px-Synthese%2B.svg.png -O rgb.png
# Out:
# --2024-07-29 22:08:27--  https://upload.wikimedia.org/wikipedia/commons/thumb/e/e0/Synthese%2B.svg/1200px-Synthese%2B.svg.png
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.154.240, 2620:0:861:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.154.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39120 (38K) [image/png]
# Saving to: ‘rgb.png’
#
# rgb.png             100%[===================>]  38.20K  --.-KB/s    in 0.04s
#
# 2024-07-29 22:08:28 (1.06 MB/s) - ‘rgb.png’ saved [39120/39120]

# %% [markdown]
# #Practice 3
#
# Using OpenCV implement some image transformation such as:
# * Flip
# * Resize
# * Concatenate two or more images
# * Change several pixel values

# %%
#Implement Practice 3 here

# %% [markdown]
# #Now, it is up to you!
# Take a look at the link image. Try to find the tomato and the tennis ball. Use functions and search for new ones!
#
# The final result should be an image with a rectangle bounding the tomato.

# %%
# !wget https://cdn.pixabay.com/photo/2018/08/18/15/39/tomato-3614967_960_720.jpg -O salad.png
# !wget https://bit.ly/3Bxo9HJ -O tennisball.png
im_salad = cv2.imread('salad.png', cv2.IMREAD_COLOR)
im_tennis = cv2.imread('tennisball.png', cv2.IMREAD_COLOR)
cv2_imshow(im_salad)
cv2_imshow(im_tennis)
# Out:
# --2024-07-29 22:08:28--  https://cdn.pixabay.com/photo/2018/08/18/15/39/tomato-3614967_960_720.jpg
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 104.18.40.96, 172.64.147.160, 2606:4700:4400::6812:2860, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|104.18.40.96|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 261144 (255K) [binary/octet-stream]
# Saving to: ‘salad.png’
#
# salad.png           100%[===================>] 255.02K  --.-KB/s    in 0.04s
#
# 2024-07-29 22:08:28 (6.28 MB/s) - ‘salad.png’ saved [261144/261144]
#
# --2024-07-29 22:08:28--  https://bit.ly/3Bxo9HJ
# Resolving bit.ly (bit.ly)... 67.199.248.10, 67.199.248.11
# Connecting to bit.ly (bit.ly)|67.199.248.10|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/offsouza/color-segmentation/blob/master/images/bola.jpg?raw=true [following]
# --2024-07-29 22:08:28--  https://github.com/offsouza/color-segmentation/blob/master/images/bola.jpg?raw=true
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/offsouza/color-segmentation/raw/master/images/bola.jpg [following]
# --2024-07-29 22:08:29--  https://github.com/offsouza/color-segmentation/raw/master/images/bola.jpg
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/offsouza/color-segmentation/master/images/bola.jpg [following]
# --2024-07-29 22:08:29--  https://raw.githubusercontent.com/offsouza/color-segmentation/master/images/bola.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29181 (28K) [image/jpeg]
# Saving to: ‘tennisball.png’
#
# tennisball.png      100%[===================>]  28.50K  --.-KB/s    in 0s
#
# 2024-07-29 22:08:29 (85.6 MB/s) - ‘tennisball.png’ saved [29181/29181]
# <PIL.Image.Image image mode=RGB size=960x638>
# <PIL.Image.Image image mode=RGB size=799x428>
