# %% [markdown]
# ## Complexidade & Notação Big-O

# %% [markdown]
# ![Picture title](image-20220915-175646.png)

# %% [markdown]
# ### Qual a complexidade dos pseudo-códigos abaixo?

# %%
import matplotlib.pyplot as plt

def f0(N):    
    ......

def f1(N):    
    for i in range(N):
        .....    

def f2(N):
    
    for i in range(N):
        .....

    for i in range(N):
        .....

def f3(N):

    
    for i in range(N):        
        for j in range(N):
            .....
    
    

def f4(N):

    for i in range(int(N/2)):
        ......
        
    
def f5(N):

    for i in range(N*N):
        ....

def f6(N):
    i=1
    while(i<N)
        i *= 2
        ....

# %% [markdown]
# TAREFA: Calcule o número de passos e apresente um gráfico que embase a sua resposta da notação BigO. Abaixo um exemplo de como plotar um gráfico utilizando o pyplot

# %%
x = [0,1,2,3,4]
y1 = [0,2,4,6,8]
y2 = [2,3,4,5,6]
y3 = [0,5,10,15,20]


plt.plot(x,y1,label = 'Serie 1')
plt.plot(x,y2,label = 'Serie 2')
plt.plot(x,y3,label = 'Serie 3')
plt.legend()
plt.show()

# %% [markdown]
# Apresente exemplos de funções:

# %% [markdown]
# Logaritmica(log n)

# %%
#Code Here

# %% [markdown]
# N * Log (N)

# %%
#Code Here

# %% [markdown]
# Exponencial (2^N)

# %%
#Code Here

# %% [markdown]
# ### Qual a complexidade dos algoritmos que já vimos?

# %% [markdown]
# Recursão (caso médio):

# %% [markdown]
# Busca em listas (desordenadas):

# %% [markdown]
# Ordenação (Seleção, Inserção):

# %% [markdown]
# Busca em árvore binária:

# %% [markdown]
# Tabela Hash:

# %% [markdown]
# Consumir de uma Pilha ou Fila:

# %% [markdown]
# ## Programação Dinâmica

# %%
import time
def FibonacciR(n):
    if n<0:
        print("Incorrect input")
    # First Fibonacci number is 0
    elif n==0:
        return 0
    # Second Fibonacci number is 1
    elif n==1:
        return 1
    else:
        return FibonacciR(n-1)+FibonacciR(n-2)

# %%
def FibonacciDP(n,computed={0:0,1:1}):
  
  if n not in computed:
    computed[n] = FibonacciDP(n-1,computed) + FibonacciDP(n-2,computed)
  
  return computed[n]

# %%
for N in range(5,41,5):
    t1 = time.process_time()
    fib1 = FibonacciR(N)
    t2 = time.process_time()
    recTime= t2-t1


    t1 = time.process_time()
    fib2 = FibonacciDP(N)
    t2 = time.process_time()
    dpTime = t2-t1
    print(N,fib1,fib2)
    print("Time REC: {0:.7f}".format(recTime))
    print("Time  DP: {0:.7f}".format(dpTime))
# Out:
# 5 5 5
# Time REC: 0.0000103
# Time  DP: 0.0000038
# 10 55 55
# Time REC: 0.0000338
# Time  DP: 0.0000022
# 15 610 610
# Time REC: 0.0002499
# Time  DP: 0.0000013
# 20 6765 6765
# Time REC: 0.0036163
# Time  DP: 0.0000072
# 25 75025 75025
# Time REC: 0.0535719
# Time  DP: 0.0000147
# 30 832040 832040
# Time REC: 0.4246086
# Time  DP: 0.0000074
# 35 9227465 9227465
# Time REC: 4.8589378
# Time  DP: 0.0000071
# 40 102334155 102334155
# Time REC: 51.1816043
# Time  DP: 0.0000092

# %% [markdown]
# ### Trabalho

# %% [markdown]
# Maior Subsequência Comum (Longest Common Subsequence)

# %% [markdown]
# - Encontrar o comprimento da maior subsequência entre duas sequências. Subsequência é uma sequência que aparece na mesma ordem, porém não necessariamente contígua.

# %% [markdown]
# - Input “ABCDGH” e “AEDFHR” gera “ADH” (tam = 3)

# %% [markdown]
# - Input “AGGTAB” e “GXTXAYB” gera “GTAB” (tam = 4)

# %% [markdown]
# Apresente a solução recursiva vs programação dinâmica. Ilustre a complexidade com gráficos e notação Big O.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e80bbd5a-10ec-49f1-b63d-e8a4f335919b' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
