# %% [markdown]
# <a href="https://colab.research.google.com/github/andrehochuli/teaching/blob/main/ComputerVision%20/Lecture%2010%20-CNN%20Applications%20and%20Tricks/Exercicio_Simpsons_DataAug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #The Simpsons classification

# %%
import numpy as np
import cv2, glob
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import datasets, layers, models, losses
from tensorflow.keras.models import Model
from sklearn import metrics

#To ensure reproducibility
#we set the random seed
seed_number = 10
tf.random.set_seed(seed_number)
np.random.seed(seed_number)

# %%
#Auxiliary Function to plot images side by side
def plot_sidebyside(img_list,titles,colormap=None,figsize=(12,6)):
  n = len(img_list)
  figure, axis = plt.subplots(1, n, figsize=figsize)

  for i in range(n):
    axis[i].imshow(img_list[i], cmap=colormap)
    axis[i].set_title(titles[i])
    axis[i].axis('off')
  # Combine all the operations and display
  plt.show()

#Plot dataset samples
def plot_dataset(ds, lbls_name):
  N_SAMPLES = 10
  for i in range(5):
    for x,y in ds.take(1):

      x = x.numpy()
      x = np.squeeze(x)
      y = y.numpy()
      plot_sidebsyide(x[:N_SAMPLES],
                      y[:N_SAMPLES],'gray')

#Plot a training history
def plot_history(history):
  print(history.history.keys())
  # summarize history for accuracy
  plt.plot(history.history['acc'])
  plt.plot(history.history['val_acc'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.show()
  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.show()

# %%
# !wget https://github.com/andrehochuli/teaching/raw/main/datasets/Simpsons.zip -O Simpsons.zip
# Out:
# --2023-10-23 21:31:48--  https://github.com/andrehochuli/teaching/raw/main/datasets/Simpsons.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/andrehochuli/teaching/main/datasets/Simpsons.zip [following]
# --2023-10-23 21:31:48--  https://raw.githubusercontent.com/andrehochuli/teaching/main/datasets/Simpsons.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14750621 (14M) [application/zip]
# Saving to: ‘Simpsons.zip’
#
# Simpsons.zip        100%[===================>]  14.07M  --.-KB/s    in 0.1s
#
# 2023-10-23 21:31:49 (113 MB/s) - ‘Simpsons.zip’ saved [14750621/14750621]

# %%
# !rm -rf Simpsons
# !unzip -qo Simpsons.zip

# !ls Simpsons/Treino/bart | wc -l
# !ls Simpsons/Treino/homer | wc -l
# !ls Simpsons/Treino/marge | wc -l
# Out:
# 78
# 61
# 24

# %%
import os
import random
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img

# !rm -rf Simpsons
# !unzip -qo Simpsons.zip

for names in ['bart','family','lisa','homer','maggie','marge']:

  print("Names: ")
  # Directory containing the original images
  original_dir = f'./Simpsons/Treino/{names}'


  # Desired number of augmented images (total images after augmentation should be 200)
  target_num_images = 200

  # Create an ImageDataGenerator for data augmentation
  datagen = ImageDataGenerator(
      rotation_range=20,
      width_shift_range=0.1,
      height_shift_range=0.1,
      shear_range=0.2,
      zoom_range=0.2,
      horizontal_flip=True,
      vertical_flip=True,
      fill_mode='nearest'
  )

  # List original images in the directory
  original_images = os.listdir(original_dir)
  print(original_images)
  # Continue until we have 200 images

  while len(os.listdir(original_dir)) < target_num_images:
      # Choose a random image from the original set
      img_name = random.choice(original_images)
      img_path = os.path.join(original_dir, img_name)

      # Load the image and convert it to a Numpy array
      img = load_img(img_path)
      x = img_to_array(img)
      x = x.reshape((1,) + x.shape)
      print("Names: ", names, len(os.listdir(original_dir)))
      # Generate augmented images and save them
      i = 0
      for batch in datagen.flow(x, batch_size=1):
          augmented_image = array_to_img(batch[0])
          augmented_image.save(os.path.join(original_dir, f'augmented_{i}_{img_name}'))
          i += 1
          if i >= 10:  # Adjust the number of augmented images per original image as needed
              break
# Out:
# Names:
# ['bart010.jpg', 'bart064.jpg', 'bart004.jpg', 'bart055.jpg', 'bart032.jpg', 'bart027.jpg', 'bart019.jpg', 'bart073.jpg', 'bart037.jpg', 'bart079.jpg', 'bart043.jpg', 'bart009.jpg', 'bart061.jpg', 'bart012.jpg', 'bart076.jpg', 'bart071.jpg', 'bart045.jpg', 'bart072.jpg', 'bart080.jpg', 'bart078.jpg', 'bart006.jpg', 'bart007.jpg', 'bart039.jpg', 'bart075.jpg', 'bart036.jpg', 'bart033.jpg', 'bart051.jpg', 'bart023.jpg', 'bart021.jpg', 'bart005.jpg', 'bart030.jpg', 'bart063.jpg', 'bart003.jpg', 'bart011.jpg', 'bart062.jpg', 'bart056.jpg', 'bart054.jpg', 'bart008.jpg', 'bart077.jpg', 'bart046.jpg', 'bart016.jpg', 'bart057.jpg', 'bart059.jpg', 'bart047.jpg', 'bart070.jpg', 'bart014.jpg', 'bart013.jpg', 'bart026.jpg', 'bart031.jpg', 'bart022.jpg', 'bart040.jpg', 'bart067.jpg', 'bart041.jpg', 'bart060.jpg', 'bart053.jpg', 'bart029.jpg', 'bart024.jpg', 'bart065.jpg', 'bart020.jpg', 'bart034.jpg', 'bart001.jpg', 'bart044.jpg', 'bart068.jpg', 'bart035.jpg', 'bart018.jpg', 'bart042.jpg', 'bart038.jpg', 'bart002.jpg', 'bart025.jpg', 'bart050.jpg', 'bart069.jpg', 'bart028.jpg', 'bart052.jpg', 'bart017.jpg', 'bart066.jpg', 'bart074.jpg', 'bart015.jpg', 'bart048.jpg']
# Names:  bart 78
# Names:  bart 88
# Names:  bart 98
# Names:  bart 98
# Names:  bart 108
# Names:  bart 118
# Names:  bart 128
# Names:  bart 138
# Names:  bart 148
# Names:  bart 158
# Names:  bart 168
# Names:  bart 168
# Names:  bart 178
# Names:  bart 188
# Names:  bart 198
# Names:
# ['family024.jpg', 'family003.jpg', 'family015.jpg', 'family014.jpg', 'family021.jpg', 'family018.jpg', 'family013.jpg', 'family017.jpg', 'family025.jpg', 'family009.jpg', 'family016.jpg', 'family022.jpg', 'family019.jpg', 'family005.jpg', 'family023.jpg', 'family011.jpg', 'family006.jpg', 'family007.jpg', 'family020.jpg', 'family010.jpg', 'family004.jpg', 'family002.jpg', 'family012.jpg', 'family026.jpg', 'family008.jpg', 'family001.jpg', 'family027.jpg']
# Names:  family 27
# Names:  family 37
# Names:  family 47
# Names:  family 57
# Names:  family 67
# Names:  family 77
# Names:  family 87
# Names:  family 97
# Names:  family 107
# Names:  family 117
# Names:  family 127
# Names:  family 127
# Names:  family 137
# Names:  family 147
# Names:  family 147
# Names:  family 147
# Names:  family 157
# Names:  family 157
# Names:  family 157
# Names:  family 167
# Names:  family 177
# Names:  family 177
# Names:  family 187
# Names:  family 187
# Names:  family 187
# Names:  family 187
# Names:  family 197
# Names:
# ['lisa005.jpg', 'lisa031.jpg', 'lisa007.jpg', 'lisa029.jpg', 'lisa033.jpg', 'lisa028.jpg', 'lisa006.jpg', 'lisa004.jpg', 'lisa032.jpg', 'lisa023.jpg', 'lisa013.jpg', 'lisa016.jpg', 'lisa018.jpg', 'lisa022.jpg', 'lisa017.jpg', 'lisa030.jpg', 'lisa021.jpg', 'lisa026.jpg', 'lisa027.jpg', 'lisa009.jpg', 'lisa008.jpg', 'lisa014.jpg', 'lisa001.jpg', 'lisa015.jpg', 'lisa020.jpg', 'lisa019.jpg', 'lisa012.jpg', 'lisa010.jpg', 'lisa025.jpg', 'lisa011.jpg', 'lisa024.jpg', 'lisa003.jpg', 'lisa002.jpg']
# Names:  lisa 33
# Names:  lisa 43
# Names:  lisa 53
# Names:  lisa 63
# Names:  lisa 73
# Names:  lisa 83
# Names:  lisa 83
# Names:  lisa 93
# Names:  lisa 103
# Names:  lisa 113
# Names:  lisa 123
# Names:  lisa 133
# Names:  lisa 143
# Names:  lisa 153
# Names:  lisa 163
# Names:  lisa 173
# Names:  lisa 183
# Names:  lisa 183
# Names:  lisa 183
# Names:  lisa 193
# Names:
# ['homer027.jpg', 'homer015.jpg', 'homer020.jpg', 'homer019.jpg', 'homer005.jpg', 'homer054.jpg', 'homer057.jpg', 'homer042.jpg', 'homer023.jpg', 'homer022.jpg', 'homer040.jpg', 'homer062.jpg', 'homer051.jpg', 'homer038.jpg', 'homer060.jpg', 'homer006.jpg', 'homer055.jpg', 'homer039.jpg', 'homer003.jpg', 'homer011.jpg', 'homer056.jpg', 'homer007.jpg', 'homer018.jpg', 'homer024.jpg', 'homer002.jpg', 'homer049.jpg', 'homer043.jpg', 'homer014.jpg', 'homer008.jpg', 'homer030.jpg', 'homer032.jpg', 'homer017.jpg', 'homer041.jpg', 'homer037.jpg', 'homer046.jpg', 'homer004.jpg', 'homer001.jpg', 'homer053.jpg', 'homer021.jpg', 'homer009.jpg', 'homer047.jpg', 'homer044.jpg', 'homer028.jpg', 'homer061.jpg', 'homer031.jpg', 'homer058.jpg', 'homer026.jpg', 'homer036.jpg', 'homer013.jpg', 'homer050.jpg', 'homer029.jpg', 'homer016.jpg', 'homer033.jpg', 'homer034.jpg', 'homer012.jpg', 'homer048.jpg', 'homer035.jpg', 'homer059.jpg', 'homer025.jpg', 'homer052.jpg', 'homer045.jpg']
# Names:  homer 61
# Names:  homer 71
# Names:  homer 81
# Names:  homer 91
# Names:  homer 101
# Names:  homer 111
# Names:  homer 121
# Names:  homer 131
# Names:  homer 141
# Names:  homer 141
# Names:  homer 141
# Names:  homer 151
# Names:  homer 161
# Names:  homer 171
# Names:  homer 171
# Names:  homer 181
# Names:  homer 181
# Names:  homer 191
# Names:
# ['maggie004.jpg', 'maggie011.jpg', 'maggie027.jpg', 'maggie028.jpg', 'maggie013.jpg', 'maggie006.jpg', 'maggie020.jpg', 'maggie029.jpg', 'maggie005.jpg', 'maggie023.jpg', 'maggie024.jpg', 'maggie002.jpg', 'maggie022.jpg', 'maggie025.jpg', 'maggie021.jpg', 'maggie026.jpg', 'maggie007.jpg', 'maggie030.jpg', 'maggie019.jpg', 'maggie010.jpg', 'maggie008.jpg', 'maggie016.jpg', 'maggie001.jpg', 'maggie017.jpg', 'maggie014.jpg', 'maggie018.jpg', 'maggie012.jpg', 'maggie009.jpg', 'maggie003.jpg', 'maggie015.jpg']
# Names:  maggie 30
# Names:  maggie 40
# Names:  maggie 50
# Names:  maggie 60
# Names:  maggie 70
# Names:  maggie 70
# Names:  maggie 80
# Names:  maggie 80
# Names:  maggie 90
# Names:  maggie 100
# Names:  maggie 100
# Names:  maggie 110
# Names:  maggie 120
# Names:  maggie 120
# Names:  maggie 120
# Names:  maggie 130
# Names:  maggie 140
# Names:  maggie 150
# Names:  maggie 160
# Names:  maggie 170
# Names:  maggie 170
# Names:  maggie 170
# Names:  maggie 180
# Names:  maggie 180
# Names:  maggie 180
# Names:  maggie 190
# Names:
# ['marge013.jpg', 'marge010.jpg', 'marge006.jpg', 'marge021.jpg', 'marge008.jpg', 'marge009.jpg', 'marge002.jpg', 'marge018.jpg', 'marge020.jpg', 'marge022.jpg', 'marge014.jpg', 'marge012.jpg', 'marge004.jpg', 'marge016.jpg', 'marge001.jpg', 'marge024.jpg', 'marge015.jpg', 'marge023.jpg', 'marge017.jpg', 'marge005.jpg', 'marge003.jpg', 'marge011.jpg', 'marge007.jpg', 'marge019.jpg']
# Names:  marge 24
# Names:  marge 34
# Names:  marge 44
# Names:  marge 54
# Names:  marge 64
# Names:  marge 74
# Names:  marge 84
# Names:  marge 94
# Names:  marge 94
# Names:  marge 104
# Names:  marge 114
# Names:  marge 114
# Names:  marge 124
# Names:  marge 124
# Names:  marge 124
# Names:  marge 134
# Names:  marge 134
# Names:  marge 134
# Names:  marge 144
# Names:  marge 144
# Names:  marge 154
# Names:  marge 154
# Names:  marge 164
# Names:  marge 164
# Names:  marge 164
# Names:  marge 164
# Names:  marge 164
# Names:  marge 174
# Names:  marge 184
# Names:  marge 194
# Names:  marge 194

# %%
data_dir = './Simpsons/Treino'
batch_size_ = 32
input_shape_ = (96,96,3)

train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=seed_number,
  image_size=(input_shape_[0], input_shape_[1]),
  batch_size=batch_size_)

val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=seed_number,
  image_size=(input_shape_[0], input_shape_[1]),
  batch_size=batch_size_)
# Out:
# Found 1223 files belonging to 6 classes.
# Using 979 files for training.
# Found 1223 files belonging to 6 classes.
# Using 244 files for validation.

# %%
class_names = train_ds.class_names
num_classes = len(class_names)
print(class_names)
class_names = np.array(class_names)
for img,lbl in train_ds.take(10):

  titles = []
  print(lbl)
  for i in lbl:
    titles.append(class_names[i])

  plot_sidebyside(img[:5]/255.,titles[:5])
# Out:
# ['bart', 'family', 'homer', 'lisa', 'maggie', 'marge']
# tf.Tensor([0 0 1 1 0 2 4 0 1 4 3 2 5 1 5 3 4 3 5 4 5 0 2 5 0 1 3 5 4 2 0 4], shape=(32,), dtype=int32)
# tf.Tensor([4 4 4 4 5 3 2 1 3 0 3 3 3 2 0 2 0 2 0 2 0 3 4 3 2 4 2 4 2 2 1 5], shape=(32,), dtype=int32)
# tf.Tensor([4 1 2 5 5 2 2 1 4 3 2 5 0 5 5 2 5 0 4 5 0 5 5 5 3 3 0 4 4 3 2 4], shape=(32,), dtype=int32)
# tf.Tensor([3 1 5 1 5 3 4 5 3 5 1 1 2 1 0 4 3 1 2 4 1 4 2 0 2 5 4 0 1 4 1 1], shape=(32,), dtype=int32)
# tf.Tensor([2 3 0 5 3 0 4 5 4 3 5 4 2 5 1 2 0 4 2 4 0 2 5 0 2 0 3 0 0 3 3 0], shape=(32,), dtype=int32)
# tf.Tensor([2 0 2 2 3 2 2 4 3 5 4 3 1 1 0 0 2 3 2 3 3 3 3 0 3 2 4 4 5 3 5 0], shape=(32,), dtype=int32)
# tf.Tensor([4 2 0 1 1 2 0 2 3 2 3 3 1 4 0 1 0 5 0 3 2 4 0 1 3 2 5 0 0 2 5 0], shape=(32,), dtype=int32)
# tf.Tensor([4 2 1 5 1 2 4 5 2 4 1 2 3 4 1 5 2 2 0 1 5 1 2 2 0 0 0 3 5 2 1 1], shape=(32,), dtype=int32)
# tf.Tensor([3 5 5 1 1 5 2 3 2 5 0 0 0 4 4 0 3 3 5 2 3 0 0 0 1 0 0 5 0 0 1 5], shape=(32,), dtype=int32)
# tf.Tensor([1 5 4 1 1 1 2 4 4 5 4 0 3 3 5 4 5 5 3 5 2 5 1 5 0 3 5 3 0 1 0 1], shape=(32,), dtype=int32)

# %%
y_train = []
x_train = []
#test_ds = test_ds.map(lambda x, y: (layers.Rescaling(1./255)(x), y))

for img, labels in train_ds:
    y_train.extend(labels.numpy())
    x_train.extend(img)

y_train = np.array(y_train)
x_train = np.array(x_train)

# %%
ret = np.unique(y_train,return_counts=True)
print(class_names)
print(ret)
# Out:
# ['bart' 'family' 'homer' 'lisa' 'maggie' 'marge']
# (array([0, 1, 2, 3, 4, 5], dtype=int32), array([171, 159, 166, 155, 167, 161]))

# %%
model = models.Sequential()

#Feature Learning (Convolutions)
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape_))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape_))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu', input_shape=input_shape_))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape_))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape_))
model.add(layers.MaxPooling2D((2, 2)))
######################################

# Fully-Connect (Classifcation)
model.add(layers.Dropout(0.25))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(num_classes,activation='softmax'))



model.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_50 (Conv2D)          (None, 94, 94, 32)        896
#
#  max_pooling2d_32 (MaxPooli  (None, 47, 47, 32)        0
#  ng2D)
#
#  conv2d_51 (Conv2D)          (None, 45, 45, 64)        18496
#
#  max_pooling2d_33 (MaxPooli  (None, 22, 22, 64)        0
#  ng2D)
#
#  conv2d_52 (Conv2D)          (None, 20, 20, 128)       73856
#
#  max_pooling2d_34 (MaxPooli  (None, 10, 10, 128)       0
#  ng2D)
#
#  conv2d_53 (Conv2D)          (None, 8, 8, 64)          73792
#
#  max_pooling2d_35 (MaxPooli  (None, 4, 4, 64)          0
#  ng2D)
#
#  conv2d_54 (Conv2D)          (None, 2, 2, 32)          18464
#
#  max_pooling2d_36 (MaxPooli  (None, 1, 1, 32)          0
#  ng2D)
#
#  dropout_17 (Dropout)        (None, 1, 1, 32)          0
#
#  flatten_16 (Flatten)        (None, 32)                0
#
#  dense_49 (Dense)            (None, 512)               16896
#
#  dense_50 (Dense)            (None, 128)               65664
#
#  dense_51 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 268838 (1.03 MB)
# Trainable params: 268838 (1.03 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs_ = 10
model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["acc"])
history = model.fit(train_ds, batch_size=batch_size_, epochs=epochs_, validation_data=val_ds)
# Out:
# Epoch 1/10
# 31/31 [==============================] - 20s 570ms/step - loss: 2.8501 - acc: 0.1706 - val_loss: 1.7918 - val_acc: 0.1967
# Epoch 2/10
# 13/31 [===========>..................] - ETA: 8s - loss: 1.7922 - acc: 0.1875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-115-50c7d3d7af39> in <cell line: 3>()
#       1 epochs_ = 10
#       2 model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["acc"])
# ----> 3 history = model.fit(train_ds, batch_size=batch_size_, epochs=epochs_, validation_data=val_ds)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1781                         ):
#    1782                             callbacks.on_train_batch_begin(step)
# -> 1783                             tmp_logs = self.train_function(iterator)
#    1784                             if data_handler.should_sync:
#    1785                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     829
#     830       with OptionalXlaContext(self._jit_compile):
# --> 831         result = self._call(*args, **kwds)
#     832
#     833       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     865       # In this case we have created variables on the first call, so we run the
#     866       # defunned version which is guaranteed to never create variables.
# --> 867       return tracing_compilation.call_function(
#     868           args, kwds, self._no_variable_creation_config
#     869       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1262         and executing_eagerly):
#    1263       # No tape is watching; skip to running the function.
# -> 1264       return self._inference_function.flat_call(args)
#    1265     forward_backward = self._select_forward_and_backward_functions(
#    1266         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in flat_call(self, args)
#     215   def flat_call(self, args: Sequence[core.Tensor]) -> Any:
#     216     """Calls with tensor inputs and returns the structured output."""
# --> 217     flat_outputs = self(*args)
#     218     return self.function_type.pack_output(flat_outputs)
#     219
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in __call__(self, *args)
#     250         with record.stop_recording():
#     251           if self._bound_context.executing_eagerly():
# --> 252             outputs = self._bound_context.call_function(
#     253                 self.name,
#     254                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1477     cancellation_context = cancellation.context()
#    1478     if cancellation_context is None:
# -> 1479       outputs = execute.execute(
#    1480           name.decode("utf-8"),
#    1481           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58         for t in inputs
#      59     ]
# ---> 60     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                         inputs, attrs, num_outputs)
#      62   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
plot_history(history)
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
model = models.Sequential()

#Feature Learning (Convolutions)
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape_))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape_))
model.add(layers.Conv2D(128, (3, 3), activation='relu', input_shape=input_shape_))
model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape_))
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape_))

######################################

# Fully-Connect (Classifcation)
model.add(layers.Dropout(0.10))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(num_classes,activation='softmax'))

model.summary()

# %%
epochs_ = 10
model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["acc"])
history = model.fit(train_ds, batch_size=batch_size_, epochs=epochs_, validation_data=val_ds)
# Out:
# Epoch 1/10
# Exception ignored in: <function _xla_gc_callback at 0x793ebce65990>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# 7/7 [==============================] - 77s 2s/step - loss: 239.9795 - acc: 0.1823 - val_loss: 3.4486 - val_acc: 0.1400
# Epoch 2/10
# 7/7 [==============================] - 19s 3s/step - loss: 3.0095 - acc: 0.1921 - val_loss: 1.8049 - val_acc: 0.0200
# Epoch 3/10
# 7/7 [==============================] - 18s 2s/step - loss: 1.7862 - acc: 0.2660 - val_loss: 1.8156 - val_acc: 0.2800
# Epoch 4/10
# 7/7 [==============================] - 18s 3s/step - loss: 1.7892 - acc: 0.2956 - val_loss: 1.8083 - val_acc: 0.2800
# Epoch 5/10
# 7/7 [==============================] - 17s 2s/step - loss: 1.7867 - acc: 0.2956 - val_loss: 1.8007 - val_acc: 0.2800
# Epoch 6/10
# 7/7 [==============================] - 15s 2s/step - loss: 1.7830 - acc: 0.3005 - val_loss: 1.7963 - val_acc: 0.2800
# Epoch 7/10
# 7/7 [==============================] - 16s 2s/step - loss: 1.7794 - acc: 0.3005 - val_loss: 1.7940 - val_acc: 0.2800
# Epoch 8/10
# 7/7 [==============================] - 17s 2s/step - loss: 1.7737 - acc: 0.3103 - val_loss: 1.7952 - val_acc: 0.2600
# Epoch 9/10
# 7/7 [==============================] - 19s 3s/step - loss: 1.9094 - acc: 0.3153 - val_loss: 1.7734 - val_acc: 0.2800
# Epoch 10/10
# 7/7 [==============================] - 16s 2s/step - loss: 1.7658 - acc: 0.3005 - val_loss: 1.7635 - val_acc: 0.2800

# %% [markdown]
# #Data Augmentation

# %%
data_augmentation = tf.keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(input_shape_[0],
                                  input_shape_[1],
                                  3)),
    layers.RandomRotation(0.15),
    layers.RandomZoom(0.3),
    tf.keras.layers.RandomBrightness(0.1),
    tf.keras.layers.RandomContrast(0.1)
  ]
)

for images, _ in train_ds.take(2):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = tf.keras.Sequential([
  data_augmentation, #Data Augmentation
  layers.Rescaling(1./255, input_shape=(96, 96, 3)),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.Conv2D(32, 3, padding='same', activation='relu'),

  layers.Dropout(0.1), #Regularization
  layers.Flatten(),
  layers.Dense(512, activation='relu'),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, activation='softmax')
])


model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_12 (Sequential)  (None, 96, 96, 3)         0
#
#  rescaling_1 (Rescaling)     (None, 96, 96, 3)         0
#
#  conv2d_45 (Conv2D)          (None, 96, 96, 32)        896
#
#  max_pooling2d_30 (MaxPooli  (None, 48, 48, 32)        0
#  ng2D)
#
#  conv2d_46 (Conv2D)          (None, 48, 48, 64)        18496
#
#  conv2d_47 (Conv2D)          (None, 48, 48, 128)       73856
#
#  max_pooling2d_31 (MaxPooli  (None, 24, 24, 128)       0
#  ng2D)
#
#  conv2d_48 (Conv2D)          (None, 24, 24, 64)        73792
#
#  conv2d_49 (Conv2D)          (None, 24, 24, 32)        18464
#
#  dropout_9 (Dropout)         (None, 24, 24, 32)        0
#
#  flatten_8 (Flatten)         (None, 18432)             0
#
#  dense_24 (Dense)            (None, 512)               9437696
#
#  dense_25 (Dense)            (None, 128)               65664
#
#  dense_26 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 9689638 (36.96 MB)
# Trainable params: 9689638 (36.96 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs_ = 10
model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["acc"])
history = model.fit(train_ds, batch_size=batch_size_, epochs=epochs_, validation_data=val_ds)
# Out:
# Epoch 1/10
# 7/7 [==============================] - 18s 2s/step - loss: 2.0677 - acc: 0.1921 - val_loss: 1.7470 - val_acc: 0.3400
# Epoch 2/10
# 7/7 [==============================] - 13s 2s/step - loss: 1.7313 - acc: 0.3005 - val_loss: 1.6372 - val_acc: 0.3400
# Epoch 3/10
# 7/7 [==============================] - 13s 2s/step - loss: 1.7056 - acc: 0.2512 - val_loss: 1.5822 - val_acc: 0.3400
# Epoch 4/10
# 7/7 [==============================] - 13s 2s/step - loss: 1.5820 - acc: 0.3399 - val_loss: 1.4533 - val_acc: 0.4000
# Epoch 5/10
# 7/7 [==============================] - 13s 2s/step - loss: 1.3834 - acc: 0.3990 - val_loss: 1.0837 - val_acc: 0.6200
# Epoch 6/10
# 7/7 [==============================] - 13s 2s/step - loss: 1.3614 - acc: 0.4778 - val_loss: 1.2336 - val_acc: 0.4800
# Epoch 7/10
# 7/7 [==============================] - 15s 2s/step - loss: 1.2496 - acc: 0.4975 - val_loss: 1.2979 - val_acc: 0.4400
# Epoch 8/10
# 7/7 [==============================] - 17s 2s/step - loss: 1.2003 - acc: 0.4877 - val_loss: 1.1731 - val_acc: 0.5200
# Epoch 9/10
# 7/7 [==============================] - 12s 2s/step - loss: 1.1570 - acc: 0.5468 - val_loss: 1.1793 - val_acc: 0.4600
# Epoch 10/10
# 7/7 [==============================] - 12s 2s/step - loss: 1.0798 - acc: 0.5665 - val_loss: 1.0115 - val_acc: 0.6200

# %%
plot_history(history)
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %% [markdown]
# #Transfer Learning

# %%
conv_layers =  tf.keras.applications.resnet50.ResNet50(weights='imagenet', include_top=False,
                                                        input_tensor=tf.keras.layers.Input(input_shape_),
                                                      classes=num_classes)
conv_layers.trainable = False


conv_layers.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 3)]          0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 102, 102, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 48, 48, 64)           9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 48, 48, 64)           256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 48, 48, 64)           0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 50, 50, 64)           0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 24, 24, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 24, 24, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 24, 24, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 24, 24, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 24, 24, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 24, 24, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 24, 24, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 24, 24, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 24, 24, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 24, 24, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 24, 24, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 24, 24, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 24, 24, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 24, 24, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 24, 24, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 24, 24, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 24, 24, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 24, 24, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 24, 24, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 24, 24, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 24, 24, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 24, 24, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 24, 24, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 24, 24, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 24, 24, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 24, 24, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 24, 24, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 24, 24, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 24, 24, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 24, 24, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 24, 24, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 24, 24, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 24, 24, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 12, 12, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 12, 12, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 12, 12, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 12, 12, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 12, 12, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 12, 12, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 12, 12, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 12, 12, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 12, 12, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 12, 12, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 12, 12, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 12, 12, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 12, 12, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 12, 12, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 12, 12, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 12, 12, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 12, 12, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 12, 12, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 12, 12, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 12, 12, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 12, 12, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 12, 12, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 12, 12, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 12, 12, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 12, 12, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 12, 12, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 12, 12, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 12, 12, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 12, 12, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 12, 12, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 12, 12, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 12, 12, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 12, 12, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 12, 12, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 12, 12, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 12, 12, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 12, 12, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 12, 12, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 12, 12, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 12, 12, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 12, 12, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 12, 12, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 6, 6, 256)            131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 6, 6, 256)            590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 6, 6, 1024)           525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 6, 6, 1024)           263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 6, 6, 1024)           4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 6, 6, 1024)           4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 6, 6, 1024)           0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 6, 6, 1024)           0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 6, 6, 256)            262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 6, 6, 256)            590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 6, 6, 1024)           263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 6, 6, 1024)           4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 6, 6, 1024)           0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 6, 6, 1024)           0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 6, 6, 256)            262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 6, 6, 256)            590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 6, 6, 1024)           263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 6, 6, 1024)           4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 6, 6, 1024)           0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 6, 6, 1024)           0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 6, 6, 256)            262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 6, 6, 256)            590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 6, 6, 1024)           263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 6, 6, 1024)           4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 6, 6, 1024)           0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 6, 6, 1024)           0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 6, 6, 256)            262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 6, 6, 256)            590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 6, 6, 1024)           263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 6, 6, 1024)           4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 6, 6, 1024)           0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 6, 6, 1024)           0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 6, 6, 256)            262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 6, 6, 256)            590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 6, 6, 1024)           263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 6, 6, 1024)           4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 6, 6, 1024)           0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 6, 6, 1024)           0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 3, 3, 512)            524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 3, 3, 512)            2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 3, 3, 512)            0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 3, 3, 512)            2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 3, 3, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 3, 3, 512)            0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 3, 3, 2048)           2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 3, 3, 2048)           1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 3, 3, 2048)           8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 3, 3, 2048)           8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 3, 3, 2048)           0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 3, 3, 2048)           0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 3, 3, 512)            1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 3, 3, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 3, 3, 512)            0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 3, 3, 512)            2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 3, 3, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 3, 3, 512)            0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 3, 3, 2048)           1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 3, 3, 2048)           8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 3, 3, 2048)           0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 3, 3, 2048)           0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 3, 3, 512)            1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 3, 3, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 3, 3, 512)            0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 3, 3, 512)            2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 3, 3, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 3, 3, 512)            0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 3, 3, 2048)           1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 3, 3, 2048)           8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 3, 3, 2048)           0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 3, 3, 2048)           0         ['conv5_block3_add[0][0]']
#  on)
#
# ==================================================================================================
# Total params: 23587712 (89.98 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 23587712 (89.98 MB)
# __________________________________________________________________________________________________

# %%
model = tf.keras.Sequential([
  conv_layers,
  layers.GlobalAveragePooling2D(),
  layers.Dropout(0.2),

  layers.Flatten(),

  layers.Dense(256, activation='relu'),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, activation='softmax')
])

model.summary()

epochs_ = 50
model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["acc"])
history = model.fit(train_ds, batch_size=batch_size_, epochs=epochs_, validation_data=val_ds)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 3, 3, 2048)        23587712
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dropout_10 (Dropout)        (None, 2048)              0
#
#  flatten_9 (Flatten)         (None, 2048)              0
#
#  dense_27 (Dense)            (None, 256)               524544
#
#  dense_28 (Dense)            (None, 128)               32896
#
#  dense_29 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 24145926 (92.11 MB)
# Trainable params: 558214 (2.13 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________
# Epoch 1/50
# 7/7 [==============================] - 14s 1s/step - loss: 2.3072 - acc: 0.2956 - val_loss: 1.6687 - val_acc: 0.5200
# Epoch 2/50
# 7/7 [==============================] - 10s 2s/step - loss: 1.1513 - acc: 0.5911 - val_loss: 1.2612 - val_acc: 0.5800
# Epoch 3/50
# 7/7 [==============================] - 10s 2s/step - loss: 0.6751 - acc: 0.7734 - val_loss: 1.1300 - val_acc: 0.5800
# Epoch 4/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.4017 - acc: 0.8768 - val_loss: 1.0964 - val_acc: 0.6400
# Epoch 5/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.3425 - acc: 0.8966 - val_loss: 1.0922 - val_acc: 0.5600
# Epoch 6/50
# 7/7 [==============================] - 10s 1s/step - loss: 0.3035 - acc: 0.9015 - val_loss: 1.2572 - val_acc: 0.6200
# Epoch 7/50
# 7/7 [==============================] - 10s 2s/step - loss: 0.2283 - acc: 0.9310 - val_loss: 0.9350 - val_acc: 0.6400
# Epoch 8/50
# 7/7 [==============================] - 12s 2s/step - loss: 0.1317 - acc: 0.9606 - val_loss: 0.9016 - val_acc: 0.7200
# Epoch 9/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0877 - acc: 0.9852 - val_loss: 1.0010 - val_acc: 0.7000
# Epoch 10/50
# 7/7 [==============================] - 8s 1s/step - loss: 0.0805 - acc: 0.9901 - val_loss: 0.9435 - val_acc: 0.7000
# Epoch 11/50
# 7/7 [==============================] - 10s 2s/step - loss: 0.0485 - acc: 0.9951 - val_loss: 1.1044 - val_acc: 0.7600
# Epoch 12/50
# 7/7 [==============================] - 12s 2s/step - loss: 0.0484 - acc: 0.9951 - val_loss: 1.0182 - val_acc: 0.7000
# Epoch 13/50
# 7/7 [==============================] - 8s 1s/step - loss: 0.0291 - acc: 0.9901 - val_loss: 1.0303 - val_acc: 0.7000
# Epoch 14/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0373 - acc: 0.9951 - val_loss: 1.1591 - val_acc: 0.7000
# Epoch 15/50
# 7/7 [==============================] - 8s 1s/step - loss: 0.0324 - acc: 0.9901 - val_loss: 1.2296 - val_acc: 0.7000
# Epoch 16/50
# 7/7 [==============================] - 11s 2s/step - loss: 0.0507 - acc: 0.9803 - val_loss: 1.1187 - val_acc: 0.6600
# Epoch 17/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0321 - acc: 0.9951 - val_loss: 1.4361 - val_acc: 0.7000
# Epoch 18/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0384 - acc: 0.9852 - val_loss: 1.4728 - val_acc: 0.6800
# Epoch 19/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0379 - acc: 0.9951 - val_loss: 1.3149 - val_acc: 0.6400
# Epoch 20/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0366 - acc: 0.9901 - val_loss: 1.2519 - val_acc: 0.6800
# Epoch 21/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0237 - acc: 0.9951 - val_loss: 1.2095 - val_acc: 0.6600
# Epoch 22/50
# 7/7 [==============================] - 8s 1s/step - loss: 0.0096 - acc: 1.0000 - val_loss: 1.1305 - val_acc: 0.6600
# Epoch 23/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0169 - acc: 1.0000 - val_loss: 1.1628 - val_acc: 0.7200
# Epoch 24/50
# 7/7 [==============================] - 10s 1s/step - loss: 0.0163 - acc: 0.9951 - val_loss: 1.1833 - val_acc: 0.6600
# Epoch 25/50
# 7/7 [==============================] - 8s 1s/step - loss: 0.0140 - acc: 1.0000 - val_loss: 1.0885 - val_acc: 0.6800
# Epoch 26/50
# 7/7 [==============================] - 8s 1s/step - loss: 0.0075 - acc: 1.0000 - val_loss: 1.2562 - val_acc: 0.7400
# Epoch 27/50
# 7/7 [==============================] - 10s 1s/step - loss: 0.0090 - acc: 1.0000 - val_loss: 1.2569 - val_acc: 0.7400
# Epoch 28/50
# 7/7 [==============================] - 10s 1s/step - loss: 0.0053 - acc: 1.0000 - val_loss: 1.1514 - val_acc: 0.6800
# Epoch 29/50
# 7/7 [==============================] - 8s 1s/step - loss: 0.0086 - acc: 1.0000 - val_loss: 1.1936 - val_acc: 0.7000
# Epoch 30/50
# 7/7 [==============================] - 7s 1s/step - loss: 0.0037 - acc: 1.0000 - val_loss: 1.3487 - val_acc: 0.7600
# Epoch 31/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0082 - acc: 1.0000 - val_loss: 1.1690 - val_acc: 0.7000
# Epoch 32/50
# 7/7 [==============================] - 10s 1s/step - loss: 0.0041 - acc: 1.0000 - val_loss: 1.2087 - val_acc: 0.6800
# Epoch 33/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0059 - acc: 1.0000 - val_loss: 1.2248 - val_acc: 0.7000
# Epoch 34/50
# 7/7 [==============================] - 8s 1s/step - loss: 0.0035 - acc: 1.0000 - val_loss: 1.2645 - val_acc: 0.7000
# Epoch 35/50
# 7/7 [==============================] - 10s 1s/step - loss: 0.0025 - acc: 1.0000 - val_loss: 1.2528 - val_acc: 0.7000
# Epoch 36/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0020 - acc: 1.0000 - val_loss: 1.2589 - val_acc: 0.6800
# Epoch 37/50
# 7/7 [==============================] - 10s 1s/step - loss: 0.0020 - acc: 1.0000 - val_loss: 1.2732 - val_acc: 0.6800
# Epoch 38/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0020 - acc: 1.0000 - val_loss: 1.2879 - val_acc: 0.6800
# Epoch 39/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0024 - acc: 1.0000 - val_loss: 1.2962 - val_acc: 0.6800
# Epoch 40/50
# 7/7 [==============================] - 10s 1s/step - loss: 0.0014 - acc: 1.0000 - val_loss: 1.3264 - val_acc: 0.6800
# Epoch 41/50
# 7/7 [==============================] - 10s 1s/step - loss: 0.0013 - acc: 1.0000 - val_loss: 1.3589 - val_acc: 0.7000
# Epoch 42/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0026 - acc: 1.0000 - val_loss: 1.3816 - val_acc: 0.6800
# Epoch 43/50
# 7/7 [==============================] - 8s 1s/step - loss: 0.0025 - acc: 1.0000 - val_loss: 1.3902 - val_acc: 0.7000
# Epoch 44/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0013 - acc: 1.0000 - val_loss: 1.3890 - val_acc: 0.7000
# Epoch 45/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0024 - acc: 1.0000 - val_loss: 1.3700 - val_acc: 0.6800
# Epoch 46/50
# 7/7 [==============================] - 7s 1s/step - loss: 0.0029 - acc: 1.0000 - val_loss: 1.4103 - val_acc: 0.7000
# Epoch 47/50
# 7/7 [==============================] - 10s 1s/step - loss: 0.0030 - acc: 1.0000 - val_loss: 1.4630 - val_acc: 0.7000
# Epoch 48/50
# 7/7 [==============================] - 10s 1s/step - loss: 0.0035 - acc: 1.0000 - val_loss: 1.4613 - val_acc: 0.6800
# Epoch 49/50
# 7/7 [==============================] - 13s 2s/step - loss: 0.0021 - acc: 1.0000 - val_loss: 1.5671 - val_acc: 0.7200
# Epoch 50/50
# 7/7 [==============================] - 12s 2s/step - loss: 0.0021 - acc: 1.0000 - val_loss: 1.5353 - val_acc: 0.7000

# %%
model = tf.keras.Sequential([
  conv_layers,
  layers.GlobalAveragePooling2D(),
  layers.Dropout(0.2),

  layers.Flatten(),

  layers.Dense(256, activation='relu'),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, activation='softmax')
])

model.summary()

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='my_model/model_checkpoint.h5',  # Specify the file to save the weights
    save_best_only=True,             # Save only the best model
    monitor='val_acc' ,              # Monitoring validation loss
    mode='max',
    verbose=1
)

epochs_ = 20
model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["acc"])
history = model.fit(train_ds, batch_size=batch_size_, epochs=epochs_, validation_data=val_ds, callbacks=[checkpoint_callback])
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 3, 3, 2048)        23587712
#
#  global_average_pooling2d_2  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dropout_12 (Dropout)        (None, 2048)              0
#
#  flatten_11 (Flatten)        (None, 2048)              0
#
#  dense_33 (Dense)            (None, 256)               524544
#
#  dense_34 (Dense)            (None, 128)               32896
#
#  dense_35 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 24145926 (92.11 MB)
# Trainable params: 558214 (2.13 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________
# Epoch 1/20
# Exception ignored in: <function _xla_gc_callback at 0x793ebce65990>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# 7/7 [==============================] - ETA: 0s - loss: 2.0501 - acc: 0.3202
# Epoch 1: val_acc improved from -inf to 0.34000, saving model to my_model/model_checkpoint.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 71s 2s/step - loss: 2.0501 - acc: 0.3202 - val_loss: 1.5283 - val_acc: 0.3400
# Epoch 2/20
# 7/7 [==============================] - ETA: 0s - loss: 0.9688 - acc: 0.6305
# Epoch 2: val_acc improved from 0.34000 to 0.44000, saving model to my_model/model_checkpoint.h5
# 7/7 [==============================] - 12s 2s/step - loss: 0.9688 - acc: 0.6305 - val_loss: 1.3771 - val_acc: 0.4400
# Epoch 3/20
# 7/7 [==============================] - ETA: 0s - loss: 0.6640 - acc: 0.7537
# Epoch 3: val_acc improved from 0.44000 to 0.58000, saving model to my_model/model_checkpoint.h5
# 7/7 [==============================] - 11s 2s/step - loss: 0.6640 - acc: 0.7537 - val_loss: 1.3849 - val_acc: 0.5800
# Epoch 4/20
# 7/7 [==============================] - ETA: 0s - loss: 0.4417 - acc: 0.8522
# Epoch 4: val_acc did not improve from 0.58000
# 7/7 [==============================] - 10s 1s/step - loss: 0.4417 - acc: 0.8522 - val_loss: 1.2076 - val_acc: 0.5800
# Epoch 5/20
# 7/7 [==============================] - ETA: 0s - loss: 0.3184 - acc: 0.9064
# Epoch 5: val_acc improved from 0.58000 to 0.60000, saving model to my_model/model_checkpoint.h5
# 7/7 [==============================] - 11s 2s/step - loss: 0.3184 - acc: 0.9064 - val_loss: 1.5148 - val_acc: 0.6000
# Epoch 6/20
# 7/7 [==============================] - ETA: 0s - loss: 0.2291 - acc: 0.9261
# Epoch 6: val_acc improved from 0.60000 to 0.68000, saving model to my_model/model_checkpoint.h5
# 7/7 [==============================] - 10s 1s/step - loss: 0.2291 - acc: 0.9261 - val_loss: 1.1257 - val_acc: 0.6800
# Epoch 7/20
# 7/7 [==============================] - ETA: 0s - loss: 0.1217 - acc: 0.9754
# Epoch 7: val_acc did not improve from 0.68000
# 7/7 [==============================] - 9s 1s/step - loss: 0.1217 - acc: 0.9754 - val_loss: 1.2087 - val_acc: 0.6000
# Epoch 8/20
# 7/7 [==============================] - ETA: 0s - loss: 0.1078 - acc: 0.9655
# Epoch 8: val_acc did not improve from 0.68000
# 7/7 [==============================] - 10s 1s/step - loss: 0.1078 - acc: 0.9655 - val_loss: 1.2155 - val_acc: 0.6800
# Epoch 9/20
# 7/7 [==============================] - ETA: 0s - loss: 0.0956 - acc: 0.9803
# Epoch 9: val_acc did not improve from 0.68000
# 7/7 [==============================] - 10s 1s/step - loss: 0.0956 - acc: 0.9803 - val_loss: 1.2300 - val_acc: 0.6800
# Epoch 10/20
# 7/7 [==============================] - ETA: 0s - loss: 0.0645 - acc: 0.9803
# Epoch 10: val_acc did not improve from 0.68000
# 7/7 [==============================] - 10s 2s/step - loss: 0.0645 - acc: 0.9803 - val_loss: 1.2491 - val_acc: 0.6800
# Epoch 11/20
# 7/7 [==============================] - ETA: 0s - loss: 0.0712 - acc: 0.9803
# Epoch 11: val_acc did not improve from 0.68000
# 7/7 [==============================] - 10s 1s/step - loss: 0.0712 - acc: 0.9803 - val_loss: 1.2393 - val_acc: 0.6600
# Epoch 12/20
# 7/7 [==============================] - ETA: 0s - loss: 0.0596 - acc: 0.9852
# Epoch 12: val_acc improved from 0.68000 to 0.70000, saving model to my_model/model_checkpoint.h5
# 7/7 [==============================] - 9s 1s/step - loss: 0.0596 - acc: 0.9852 - val_loss: 1.2440 - val_acc: 0.7000
# Epoch 13/20
# 7/7 [==============================] - ETA: 0s - loss: 0.0261 - acc: 1.0000
# Epoch 13: val_acc improved from 0.70000 to 0.72000, saving model to my_model/model_checkpoint.h5
# 7/7 [==============================] - 10s 1s/step - loss: 0.0261 - acc: 1.0000 - val_loss: 1.3949 - val_acc: 0.7200
# Epoch 14/20
# 7/7 [==============================] - ETA: 0s - loss: 0.0198 - acc: 1.0000
# Epoch 14: val_acc did not improve from 0.72000
# 7/7 [==============================] - 11s 2s/step - loss: 0.0198 - acc: 1.0000 - val_loss: 1.4195 - val_acc: 0.6600
# Epoch 15/20
# 7/7 [==============================] - ETA: 0s - loss: 0.0243 - acc: 0.9951
# Epoch 15: val_acc did not improve from 0.72000
# 7/7 [==============================] - 9s 1s/step - loss: 0.0243 - acc: 0.9951 - val_loss: 1.4338 - val_acc: 0.6800
# Epoch 16/20
# 7/7 [==============================] - ETA: 0s - loss: 0.0114 - acc: 1.0000
# Epoch 16: val_acc did not improve from 0.72000
# 7/7 [==============================] - 9s 1s/step - loss: 0.0114 - acc: 1.0000 - val_loss: 1.4766 - val_acc: 0.6800
# Epoch 17/20
# 7/7 [==============================] - ETA: 0s - loss: 0.0109 - acc: 1.0000
# Epoch 17: val_acc did not improve from 0.72000
# 7/7 [==============================] - 10s 1s/step - loss: 0.0109 - acc: 1.0000 - val_loss: 1.4601 - val_acc: 0.6800
# Epoch 18/20
# 7/7 [==============================] - ETA: 0s - loss: 0.0120 - acc: 1.0000
# Epoch 18: val_acc did not improve from 0.72000
# 7/7 [==============================] - 15s 2s/step - loss: 0.0120 - acc: 1.0000 - val_loss: 1.4938 - val_acc: 0.6800
# Epoch 19/20
# 7/7 [==============================] - ETA: 0s - loss: 0.0112 - acc: 1.0000
# Epoch 19: val_acc did not improve from 0.72000
# 7/7 [==============================] - 8s 1s/step - loss: 0.0112 - acc: 1.0000 - val_loss: 1.5180 - val_acc: 0.6800
# Epoch 20/20
# 7/7 [==============================] - ETA: 0s - loss: 0.0067 - acc: 1.0000
# Epoch 20: val_acc did not improve from 0.72000
# 7/7 [==============================] - 8s 1s/step - loss: 0.0067 - acc: 1.0000 - val_loss: 1.5258 - val_acc: 0.7000

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
  f'./Simpsons/Teste/',
  seed=seed_number,
  image_size=(input_shape_[0], input_shape_[1]),
  batch_size=batch_size_)
# Out:
# Found 106 files belonging to 6 classes.

# %%
model.evaluate(test_ds)
# Out:
# 4/4 [==============================] - 6s 1s/step - loss: 1.9339 - acc: 0.6415
# [1.9338523149490356, 0.6415094137191772]

# %%
loaded_model = tf.keras.models.load_model('my_model/model_checkpoint.h5')
loaded_model.evaluate(test_ds)
# Out:
# 4/4 [==============================] - 4s 700ms/step - loss: 1.8551 - acc: 0.6226
# [1.8550846576690674, 0.6226415038108826]

# %% [markdown]
# #Transfer Leaning => Fine Tunning das ultimas 2 camadas de convolução!

# %%
conv_layers.trainable=True

n_layers = len(conv_layers.layers)
print(n_layers)
for j in range(0,n_layers-7):
    conv_layers.layers[j].trainable = False



for j in range(n_layers-7,n_layers):
    conv_layers.layers[j].trainable = True

conv_layers.summary()
#base_model.layers[j].trainable = True
# Out:
# 175
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 3)]          0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 102, 102, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 48, 48, 64)           9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 48, 48, 64)           256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 48, 48, 64)           0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 50, 50, 64)           0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 24, 24, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 24, 24, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 24, 24, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 24, 24, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 24, 24, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 24, 24, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 24, 24, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 24, 24, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 24, 24, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 24, 24, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 24, 24, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 24, 24, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 24, 24, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 24, 24, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 24, 24, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 24, 24, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 24, 24, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 24, 24, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 24, 24, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 24, 24, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 24, 24, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 24, 24, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 24, 24, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 24, 24, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 24, 24, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 24, 24, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 24, 24, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 24, 24, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 24, 24, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 24, 24, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 24, 24, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 24, 24, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 24, 24, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 12, 12, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 12, 12, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 12, 12, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 12, 12, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 12, 12, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 12, 12, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 12, 12, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 12, 12, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 12, 12, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 12, 12, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 12, 12, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 12, 12, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 12, 12, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 12, 12, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 12, 12, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 12, 12, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 12, 12, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 12, 12, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 12, 12, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 12, 12, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 12, 12, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 12, 12, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 12, 12, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 12, 12, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 12, 12, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 12, 12, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 12, 12, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 12, 12, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 12, 12, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 12, 12, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 12, 12, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 12, 12, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 12, 12, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 12, 12, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 12, 12, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 12, 12, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 12, 12, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 12, 12, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 12, 12, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 12, 12, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 12, 12, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 12, 12, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 6, 6, 256)            131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 6, 6, 256)            590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 6, 6, 1024)           525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 6, 6, 1024)           263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 6, 6, 1024)           4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 6, 6, 1024)           4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 6, 6, 1024)           0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 6, 6, 1024)           0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 6, 6, 256)            262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 6, 6, 256)            590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 6, 6, 1024)           263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 6, 6, 1024)           4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 6, 6, 1024)           0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 6, 6, 1024)           0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 6, 6, 256)            262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 6, 6, 256)            590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 6, 6, 1024)           263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 6, 6, 1024)           4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 6, 6, 1024)           0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 6, 6, 1024)           0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 6, 6, 256)            262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 6, 6, 256)            590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 6, 6, 1024)           263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 6, 6, 1024)           4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 6, 6, 1024)           0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 6, 6, 1024)           0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 6, 6, 256)            262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 6, 6, 256)            590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 6, 6, 1024)           263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 6, 6, 1024)           4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 6, 6, 1024)           0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 6, 6, 1024)           0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 6, 6, 256)            262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 6, 6, 256)            590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 6, 6, 256)            1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 6, 6, 256)            0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 6, 6, 1024)           263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 6, 6, 1024)           4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 6, 6, 1024)           0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 6, 6, 1024)           0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 3, 3, 512)            524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 3, 3, 512)            2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 3, 3, 512)            0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 3, 3, 512)            2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 3, 3, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 3, 3, 512)            0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 3, 3, 2048)           2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 3, 3, 2048)           1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 3, 3, 2048)           8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 3, 3, 2048)           8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 3, 3, 2048)           0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 3, 3, 2048)           0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 3, 3, 512)            1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 3, 3, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 3, 3, 512)            0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 3, 3, 512)            2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 3, 3, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 3, 3, 512)            0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 3, 3, 2048)           1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 3, 3, 2048)           8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 3, 3, 2048)           0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 3, 3, 2048)           0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 3, 3, 512)            1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 3, 3, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 3, 3, 512)            0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 3, 3, 512)            2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 3, 3, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 3, 3, 512)            0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 3, 3, 2048)           1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 3, 3, 2048)           8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 3, 3, 2048)           0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 3, 3, 2048)           0         ['conv5_block3_add[0][0]']
#  on)
#
# ==================================================================================================
# Total params: 23587712 (89.98 MB)
# Trainable params: 3415552 (13.03 MB)
# Non-trainable params: 20172160 (76.95 MB)
# __________________________________________________________________________________________________

# %%
model = tf.keras.Sequential([
  conv_layers,
  layers.GlobalAveragePooling2D(),
  layers.Dropout(0.3),

  layers.Flatten(),
  #layers.Dense(512, activation='relu'),
  layers.Dense(256, activation='relu'),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, activation='softmax')
])

model.summary()

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='my_model/model_checkpoint.h5',  # Specify the file to save the weights
    save_best_only=True,             # Save only the best model
    monitor='val_acc' ,              # Monitoring validation loss
    mode='max',
    verbose=1
)

epochs_ = 20
model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["acc"])
history = model.fit(train_ds, batch_size=batch_size_, epochs=epochs_, validation_data=val_ds, callbacks=[checkpoint_callback])
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 3, 3, 2048)        23587712
#
#  global_average_pooling2d_5  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dropout_18 (Dropout)        (None, 2048)              0
#
#  flatten_17 (Flatten)        (None, 2048)              0
#
#  dense_52 (Dense)            (None, 256)               524544
#
#  dense_53 (Dense)            (None, 128)               32896
#
#  dense_54 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 24145926 (92.11 MB)
# Trainable params: 3973766 (15.16 MB)
# Non-trainable params: 20172160 (76.95 MB)
# _________________________________________________________________
# Epoch 1/20
# 31/31 [==============================] - ETA: 0s - loss: 0.9112 - acc: 0.7232
